# %% [markdown]
# https://keras.io/api/layers/attention_layers/attention/

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
query_input = tf.keras.Input(
    shape = (None, ),
    dtype = 'int32',
    )

# %%
value_input = tf.keras.Input(
    shape = (None, ),
    dtype = 'int32',
    )

# %%
token_embedding = tf.keras.layers.Embedding(
    input_dim = 1000,
    output_dim = 64,
    )

# %%
query_embeddings = token_embedding(query_input)

# %%
value_embeddings = token_embedding(value_input)

# %%
query_value_attention_seq = tf.keras.layers.Attention()(
    [
        query_embeddings,
        value_embeddings,
    ]
    )

# %%
query_value_attention = tf.keras.layers.GlobalAveragePooling1D()(
    query_value_attention_seq,
    )

# %%
model = tf.keras.Model(
    inputs = [
        query_input,
        value_input,
    ],
    outputs = query_value_attention
    )

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 64)     64000       ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  attention (Attention)          (None, None, 64)     0           ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['attention[0][0]']
#  alAveragePooling1D)
#
# ==================================================================================================
# Total params: 64,000
# Trainable params: 64,000
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # test with dat

# %%
import numpy as np

# %%
model.inputs
# Out:
# [<KerasTensor: shape=(None, None) dtype=int32 (created by layer 'input_1')>,
#  <KerasTensor: shape=(None, None) dtype=int32 (created by layer 'input_2')>]

# %%
query_data = np.random.randint(
    100,
    size=((5,10)),
    )
query_data
# Out:
# array([[97, 47,  9, 54, 94, 42, 45, 39, 89, 81],
#        [ 4, 45, 67, 94, 25, 18, 13, 90, 93, 57],
#        [13, 21, 78, 59, 78, 83, 50, 51, 36, 81],
#        [29, 48,  4, 39, 31, 96, 39,  5, 40, 91],
#        [91,  4, 94,  2, 76, 15, 96, 58, 38, 40]])

# %%
value_data = np.random.randint(
    100,
    size=((5,10)),
)

value_data
# Out:
# array([[65, 42, 68, 42, 64, 26, 31, 49,  7, 21],
#        [48, 30, 75, 52, 17, 66, 49, 87, 35, 90],
#        [88, 82, 74, 34, 81, 46, 25, 86, 55, 60],
#        [86, 21, 93, 95, 23, 13, 82,  7, 87, 66],
#        [17, 20, 18,  7, 58, 72, 66, 51, 23, 55]])

# %%
x = [
    query_data,
    value_data,
]

# %%
y = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
y
# Out:
# array([[ 6.89369347e-03,  8.79287533e-03, -6.83840015e-04,
#         -1.77517645e-02,  4.08895407e-03,  2.56739883e-03,
#         -9.00619198e-03, -6.93041924e-03, -2.24864506e-03,
#          1.13645298e-02,  1.57058500e-02,  6.11115899e-03,
#         -4.28590749e-04,  1.09027857e-02, -1.00573357e-02,
#          1.21797500e-02, -1.80692188e-02,  9.84489452e-05,
#         -1.18698236e-02,  1.17561659e-02,  9.85429343e-03,
#         -3.61977005e-03,  8.21386639e-04, -2.50515970e-03,
#          1.50050619e-03, -3.10167030e-04, -5.59354341e-03,
#          9.72165633e-03,  1.23127857e-02, -6.77626405e-04,
#         -1.15508754e-02,  2.25424441e-03, -7.75272120e-03,
#          8.43576435e-03,  1.30589101e-02, -4.46171174e-03,
#         -6.59923162e-03, -1.30670727e-03, -3.07497033e-03,
#          2.50749802e-03,  1.59555022e-02, -1.24135660e-02,
#          6.79527503e-03, -3.45776929e-03,  1.66326426e-02,
#          1.88657548e-02,  4.42145485e-03, -2.45717214e-03,
#          2.90108100e-03,  4.69363574e-03, -2.03316449e-03,
#          2.58711341e-04,  8.81343987e-03, -2.32522003e-03,
#          1.53739275e-02, -2.14982536e-02,  1.08793881e-02,
#          1.19948052e-02, -1.58192101e-03, -7.45851267e-03,
#          9.45803069e-04, -1.67884696e-02,  1.67598967e-02,
#         -2.23050988e-03],
#        [-2.95870297e-04,  2.03163992e-03,  2.18436308e-02,
#         -1.28879398e-02, -6.56148931e-03, -2.13681795e-02,
#          4.69616428e-03, -1.76742859e-03, -3.93423531e-03,
#         -5.24684787e-03, -1.95435826e-02,  1.04250889e-02,
#          2.54790415e-03, -6.20047469e-03,  4.15422954e-03,
#          6.44536223e-03, -1.37368096e-02, -9.19178873e-03,
#          8.35830625e-03, -1.25856120e-02, -5.11338119e-04,
#          6.37955323e-04,  8.58404790e-04, -1.84040575e-03,
#          5.66072855e-03,  1.67090143e-03, -1.85349099e-02,
#          1.36030708e-02,  8.22984986e-03,  5.37172798e-03,
#         -1.62885757e-04, -4.75138519e-03, -8.57762527e-03,
#         -4.09491407e-03,  9.87004302e-03, -2.66519329e-03,
#         -3.44652077e-03,  3.99519410e-03,  5.69120329e-03,
#          1.22431051e-02,  6.59190863e-03, -1.81552954e-02,
#          4.16967180e-03, -7.27324106e-04,  2.93626147e-03,
#          1.65199321e-02,  1.44208651e-02,  3.10937408e-03,
#         -1.63977523e-03,  5.46903675e-03, -9.88813955e-03,
#          1.46333408e-03,  3.86217143e-04,  2.78920075e-03,
#          1.25018060e-02,  1.03951311e-02, -1.93980278e-03,
#         -4.57694335e-03, -3.66742723e-03,  8.00633552e-06,
#         -1.26341917e-03, -1.08491722e-02, -1.82288829e-02,
#         -4.40558465e-03],
#        [ 5.66901034e-03, -3.71836429e-03,  1.37051772e-02,
#          2.82682423e-02,  1.39264883e-02, -9.53760929e-03,
#          3.95181449e-03, -1.22447719e-03,  4.40920517e-03,
#         -4.59807459e-03,  1.60277598e-02, -5.24994405e-03,
#         -1.86751562e-03,  9.48049966e-03, -9.39406268e-03,
#          8.88692588e-03, -1.90157909e-02, -2.15657265e-03,
#          1.33726653e-02,  4.98972554e-03,  6.35645003e-04,
#          1.11267315e-02, -1.18243697e-04,  2.23084129e-02,
#         -4.67286771e-03, -3.74899851e-03,  7.84534030e-03,
#          5.56244608e-03,  9.81707033e-03, -2.09096354e-03,
#          2.12439857e-02,  1.43291187e-02, -2.01524347e-02,
#          7.02749426e-03, -2.91861268e-03, -1.55627336e-02,
#          2.08180808e-02, -1.49891879e-02,  1.54682936e-03,
#         -3.59751051e-03, -6.20040344e-03,  1.12658488e-02,
#         -5.13492152e-03, -1.75046772e-02, -1.88455470e-02,
#         -2.76469835e-03, -2.27016471e-02,  5.22474293e-03,
#         -2.25126743e-02,  6.66579977e-03, -1.34783136e-02,
#          3.99967190e-03, -3.43639767e-05,  1.21125635e-02,
#         -8.62477627e-03, -8.85487651e-04, -9.62612592e-03,
#          1.32423197e-03, -8.33325740e-03, -2.92536715e-04,
#          3.54548404e-03, -6.09248737e-03,  1.78831574e-02,
#         -5.46198571e-03],
#        [ 1.43894153e-02, -2.54125358e-03,  1.06508685e-02,
#          2.70576240e-03,  1.40665965e-02, -1.02384035e-02,
#          1.21911021e-03, -1.69588663e-02,  8.92998092e-03,
#         -8.89461953e-04,  8.74108449e-03,  6.05557580e-03,
#         -3.04030790e-03,  1.24492422e-02, -2.46022665e-03,
#         -1.56840645e-02, -2.54178466e-03, -2.54448713e-03,
#          1.44836202e-03, -4.01807856e-03,  2.35340884e-03,
#          1.52228051e-03,  7.91176222e-03,  6.96391379e-03,
#         -1.19389519e-02, -5.89321507e-03, -3.01920855e-03,
#         -4.75844281e-04,  8.20138026e-03,  3.34757438e-04,
#          1.52009847e-02,  4.28504078e-03, -1.33691607e-02,
#         -3.34482640e-03,  1.99958943e-02, -6.71745744e-03,
#          6.75929198e-03, -5.74666495e-03,  5.28047839e-03,
#          5.18461340e-04, -3.83224641e-03,  3.98854958e-03,
#         -3.33669665e-03, -4.36720205e-03, -1.18332487e-02,
#          6.58057164e-03,  2.75047333e-03, -7.21660908e-03,
#         -4.81424388e-03, -1.64888632e-02, -5.90861356e-03,
#          1.15692522e-02,  1.24341929e-02, -4.66292491e-03,
#         -9.25518014e-03,  7.74847460e-04,  2.42045708e-03,
#          2.69213668e-03,  1.66421046e-03, -1.05562657e-02,
#          7.80393789e-03, -1.53619247e-02,  3.95146292e-03,
#          6.69580593e-04],
#        [-5.68763493e-03,  1.76227023e-03,  4.89048846e-03,
#         -4.05904837e-03, -1.15113927e-03, -9.96834598e-03,
#          1.66880654e-03, -1.07242982e-03,  2.09242804e-03,
#         -4.77698341e-04,  3.58914654e-03,  9.08643648e-04,
#         -3.32707679e-03, -1.75425429e-02, -3.25401011e-03,
#         -6.70930138e-03, -2.32854416e-03, -2.17084512e-02,
#         -2.37405091e-03,  1.54694766e-02, -6.60275063e-03,
#          2.40934780e-03, -1.42647175e-03, -3.32623976e-03,
#          1.15343602e-03, -1.68337952e-03, -6.84498390e-03,
#          7.73021718e-03,  5.40976319e-03,  8.14380683e-03,
#          1.84171665e-02,  1.39862476e-02, -1.49880815e-02,
#          7.08264718e-03,  1.36750061e-02,  2.87509756e-03,
#         -3.20413662e-03, -1.35025186e-02,  9.41713713e-03,
#          1.68485753e-03,  1.13197956e-02, -1.20020732e-02,
#         -1.30865294e-02, -4.30866936e-03, -1.35019068e-02,
#          2.56838789e-03,  8.40322673e-03, -4.97270594e-05,
#         -2.21732608e-03, -1.26123456e-02, -2.09482759e-03,
#          5.83690312e-03,  1.08103212e-02, -2.30825669e-03,
#         -1.03597585e-02, -4.88307932e-03, -5.97138936e-03,
#         -9.53730487e-04, -1.33912368e-02, -1.09421127e-02,
#          9.88317467e-03, -1.91006605e-02, -4.10943571e-03,
#          1.30172204e-02]], dtype=float32)

# %%
y.shape
# Out:
# (5, 64)

# %% [markdown]
# # end
